# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("company_sales_data.csv")
data.head()
# Out:
#    month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# 0             1       2500      1500        5200         9200     1200
# 1             2       2630      1200        5100         6100     2100
# 2             3       2140      1340        4550         9550     3550
# 3             4       3400      1130        5870         8870     1870
# 4             5       3600      1740        4560         7760     1560
#
#    moisturizer  total_units  total_profit
# 0         1500        21100        211000
# 1         1200        18330        183300
# 2         1340        22470        224700
# 3         1130        22270        222700
# 4         1740        20960        209600

# %%
x = np.array(data.month_number)
y = np.array(data.total_profit)

plt.plot(x, y, 'r', marker='o')
plt.title('Total profit by month')
plt.xlabel("Month")
plt.xticks(np.arange(x.min(), x.max()+1))
plt.grid()
plt.ylabel("USD")

plt.legend(['Red Total'], loc='upper center')

# %%
x = np.array(data.month_number)
y = np.array(data.facecream)
y1 = np.array(data.facewash)
y2 = np.array(data.toothpaste)
y3 = np.array(data.bathingsoap)
y4 = np.array(data.shampoo)
y5 = np.array(data.moisturizer)

plt.plot(x, y, marker='o')
plt.plot(x, y1, marker='v')
plt.plot(x, y2, marker='p')
plt.plot(x, y3, marker='x')
plt.plot(x, y4, marker='o')
plt.plot(x, y5, marker='o')
plt.title('Total profit by month')
plt.xlabel("Month")
plt.xticks(np.arange(x.min(), x.max()+1))
plt.grid()
plt.ylabel("USD")

plt.legend(['Facecream', 'Facewash', 'Toothpaste', 'Bathingsoap', 'Shampoo', 'Moisturizer'], loc='upper right')

# %%
width =0.3
plt.bar(x, y1, width=width)
plt.bar(x+width, y2, width=width)
plt.title('Bar chart of Facewash and Toothpaste')
plt.xlabel("Month")
plt.grid()
plt.ylabel("USD")
plt.legend(['Facewash', 'Toothpaste'])
# plt.xticks(np.arange(x.min(), x.max()+1))
plt.show()

# %%
import matplotlib.gridspec as gridspec

fig = plt.figure(figsize=(10,10),tight_layout=True)
gs = gridspec.GridSpec(2, 2)

ax = fig.add_subplot(gs[0, :])
ax.plot(x, y, 'r', marker='o')
ax.set_title('Total profit by month')
ax.set_xlabel("Month")
ax.set_xticks(x)
ax.grid()
ax.set_ylabel("USD")
ax.legend(['Red Total'], loc='upper center')

ax = fig.add_subplot(gs[1, 0])
ax.plot(x, y, marker='o')
ax.plot(x, y1, marker='v')
ax.plot(x, y2, marker='p')
ax.plot(x, y3, marker='x')
ax.plot(x, y4, marker='o')
ax.plot(x, y5, marker='o')
ax.set_title('Total profit by month')
ax.set_xlabel("Month")
ax.set_xticks(x)
ax.grid()
ax.set_ylabel("USD")
ax.legend(['Facecream', 'Facewash', 'Toothpaste', 'Bathingsoap', 'Shampoo', 'Moisturizer'], loc='upper right')

ax = fig.add_subplot(gs[1, 1])
ax.bar(x, y1, width=width)
ax.bar(x+width, y2, width=width)
ax.set_title('Bar chart of Facewash and Toothpaste')
ax.set_xlabel("Month")
ax.grid()
ax.set_ylabel("USD")
ax.legend(['Facewash', 'Toothpaste'])
ax.set_xticks(x)

fig.align_labels()

plt.show()
